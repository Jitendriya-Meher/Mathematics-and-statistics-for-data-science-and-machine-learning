# %%
import pandas as pd

# %%
df = pd.read_csv('income.csv',
                names=['income','count'],
                skiprows=1
                )
df.head()
# Out:
#    income  count
# 0    5000   4371
# 1   10000   3295
# 2   15000   5825
# 3   20000   6047
# 4   25000   6097

# %%
df.plot(x='income',y='count', kind='bar')
# Out:
# <AxesSubplot: xlabel='income'>

# %%
df.plot(x='income',y='count', kind='bar',logy=True)
# Out:
# <AxesSubplot: xlabel='income'>
